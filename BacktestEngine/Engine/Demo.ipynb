# %% [markdown]
# # Run the backtest code

# %%
# !python Main.py -o ./Results/Demo -c Config/Demo_config.json
# Out:
# OUTPUTDIR --> ./Results/Demo
#
#
# {'symbol': 'bu', 'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'TestPrice': 'MidPrice', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.1, 'start': '2016-01-01', 'split': '2016-07-01', 'valid_split': '2016-10-01', 'end': '2016-12-31'}
# ====================
# bu1606 /home/runmin/Documents/Qishi/tick2016//bu
# 0
# ID trade_range transition_begin transition_end
# 1606 ['2015-11-1', '2016-5-1'] 2016-01-01 00:00:00 2016-03-01 00:00:00
# probability table:  20160104.0 20160229.0
# bu1609 /home/runmin/Documents/Qishi/tick2016//bu
# 0
# ID trade_range transition_begin transition_end
# 1609 ['2016-2-1', '2016-8-1'] 2016-03-01 00:00:00 2016-07-01 00:00:00
# probability table:  20160301.0 20160630.0
# bu1612 /home/runmin/Documents/Qishi/tick2016//bu
# 0
# ID trade_range transition_begin transition_end
# 1612 ['2016-6-1', '2016-11-15'] 2016-07-01 00:00:00 2016-11-01 00:00:00
# bu1706 /home/runmin/Documents/Qishi/tick2016//bu
# 0
# ID trade_range transition_begin transition_end
# 1706 ['2016-10-15', '2017-1-31'] 2016-11-01 00:00:00 2016-12-31 00:00:00
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # Get results

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("/home/runmin/Documents/Qishi/QishiQR/BacktestEngine")

from glob import glob
import pickle
import matplotlib.pyplot as plt
import Backtesting

RESULT_DIR = "./Results/Demo/"

files = glob(RESULT_DIR+"/*.pkl")

Tester_Results = []
for idx, file in enumerate(files):
    with  open(file,"rb") as f:
        Tester_Results.append(pickle.load(f))

    print("\n================================================================")
    params = Tester_Results[-1]["globalPara"]
    print("file_path = ", file)
    
    for key, item in Tester_Results[-1]["localPara"].items():
        print("{} = {}".format(key, item))
    
    fig, ax = plt.subplots(1,2, figsize=(16,8))
    Tester_Results[-1]["insample"].ensemble.ensembles[0].result.benchmark.plot(ax=ax[0])
    Tester_Results[-1]["insample"].plot(ax=ax[0])
    Tester_Results[-1]["outsample"].ensemble.ensembles[0].result.benchmark.plot(ax=ax[1])
    Tester_Results[-1]["outsample"].plot(ax=ax[1])
    
    ax[0].legend().set_visible(False)
    ax[0].set_xlabel("Date")
    ax[0].set_title("Equity curve - Insample")
    ax[1].set_xlabel("Datae")
    ax[1].set_title("Equity curve - Insample")
    plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# ================================================================
# file_path =  ./Results/Demo/Result_0.pkl
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# tca = -1
# offset = 0.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31

# %%
.
