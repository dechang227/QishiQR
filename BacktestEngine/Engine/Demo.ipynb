# %% [markdown]
# # Run the backtest code

# %%
# !python Main.py -o ./Results/Demo -c Config/Demo_config.json
# Out:
# OUTPUTDIR --> ./Results/Demo
#
#
# {'symbol': 'bu', 'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'TestPrice': 'MidPrice', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.1}
# ====================
# bu1606 /home/runmin/Documents/Qishi/tick2016//bu
# 0
# ID trade_range transition_begin transition_end
# 1606 ['2015-11-1', '2016-5-1'] 2016-01-01 00:00:00 2016-03-01 00:00:00
# probability table:  20160104.0 20160229.0
# bu1609 /home/runmin/Documents/Qishi/tick2016//bu
# 0
# ID trade_range transition_begin transition_end
# 1609 ['2016-2-1', '2016-8-1'] 2016-03-01 00:00:00 2016-07-01 00:00:00
# probability table:  20160301.0 20160630.0
# bu1612 /home/runmin/Documents/Qishi/tick2016//bu
# 0
# ID trade_range transition_begin transition_end
# 1612 ['2016-6-1', '2016-11-15'] 2016-07-01 00:00:00 2016-11-01 00:00:00
# probability table:  20160701 20160930
# bu1706 /home/runmin/Documents/Qishi/tick2016//bu
# 0
# ID trade_range transition_begin transition_end
# 1706 ['2016-10-15', '2017-1-31'] 2016-11-01 00:00:00 2016-12-31 00:00:00
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # Get results

# %%
import sys
sys.path.append("/home/runmin/Documents/Qishi/QishiQR/BacktestEngine")

from glob import glob
import pickle
import matplotlib.pyplot as plt
import Backtesting

files = glob("./Results/Demo/*.pkl")

Tester_Results = []

for idx, file in enumerate(files):
    with  open(file,"rb") as f:
        Tester_Results.append(pickle.load(f))

    print("\n=======================")
    params = Tester_Results[-1]["globalPara"]
    print(idx,":{} - Train:{}, Signal:{}, Test:{}"
          .format(params.symbol, params.TrainPrice, params.SignalPrice, params.TestPrice))
    print(Tester_Results[-1]["localPara"])
    fig, ax = plt.subplots()
    Tester_Results[-1]["model"].ensemble.ensembles[0].result.benchmark.plot(ax=ax)
    Tester_Results[-1]["model"].plot(ax=ax)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.xlabel("Date")
    plt.show()
# Out:
# =======================
# 0 :bu - Train:AvePrice2, Signal:AvePrice2, Test:MidPrice
# {'symbol': 'bu', 'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'TestPrice': 'MidPrice', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.1}
