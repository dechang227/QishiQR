# %% [markdown]
# # 0. Run the backtest code

# %%
# Ru 5min test
# !python Main.py -o ./Results/Ru_5min -c Config/Ru_5min.json > /dev/null

# Ru 10min test
# !python Main.py -o ./Results/Ru_10min -c Config/Ru_10min.json > /dev/null

# # Ru 15min test
# !python Main.py -o ./Results/Ru_15min -c Config/Ru_15min.json > /dev/null

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("/Users/simone/Documents/GitHub/QishiQR_Folk/Simeng/BacktestEngine")

import matplotlib.pyplot as plt
from PostProcessing import GetResult
from PostProcessing import OffSetAverage

def PlotResult(TesterResults):
    for ID, tester in enumerate(TesterResults):
        print("Tester=",ID)
        
        params = tester["globalPara"]
        for key, item in tester["localPara"].items():
            print("{} = {}".format(key, item))

        fig, ax = plt.subplots(1,2,figsize=(20,6))
        tester["insample"].ensemble.ensembles[0].result.benchmark.plot(ax=ax[0])
        tester["insample"].plot(ax=ax[0])
        tester["outsample"].ensemble.ensembles[0].result.benchmark.plot(ax=ax[1])
        tester["outsample"].plot(ax=ax[1])
        
        ax[0].set_xlabel("Date")
        ax[0].set_title("Equity curve - Insample")
        ax[1].set_xlabel("Datae")
        ax[1].set_title("Equity curve - Outsample")
        plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. Ru - 5min

# %%
Ru_5min_result = GetResult("Results/Ru_5min")
# Out:
# ================================================================
# Tester= 0 |file_path =  Results/Ru_5min/Result_0.pkl
#
# ================================================================
# Tester= 1 |file_path =  Results/Ru_5min/Result_1.pkl
#
# ================================================================
# Tester= 2 |file_path =  Results/Ru_5min/Result_2.pkl
#
# ================================================================
# Tester= 3 |file_path =  Results/Ru_5min/Result_3.pkl
#
# ================================================================
# Tester= 4 |file_path =  Results/Ru_5min/Result_4.pkl

# %% [markdown]
# ## 1.0 Ru - 5min offset average

# %%
Ru_5min_Offset_Average = OffSetAverage(Ru_5min_result)

Benchmark = Ru_5min_Offset_Average.GetBenchmark()
AveEqCurve = Ru_5min_Offset_Average.GetAveEquityCurve()

# Plot
fig, ax = plt.subplots(1,2, figsize=(20,6))
Benchmark['insample'].plot(ax=ax[0],label='b')
AveEqCurve['insample'].plot(ax=ax[0])
ax[0].legend(['b',2,3,4,5,6,7,8])
ax[0].set_title('Equity_Curve - insample - OffsetAverage')

Benchmark['outsample'].plot(ax=ax[1],label='b')
AveEqCurve['outsample'].plot(ax=ax[1])
ax[1].legend(['b',2,3,4,5,6,7,8])
ax[1].set_title('Equity_Curve - Outsample - OffsetAverage')
# Out:
# Text(0.5,1,'Equity_Curve - Outsample - OffsetAverage')

# %% [markdown]
# ## 1.1 Ru - 5min - no offset average

# %%
PlotResult(Ru_5min_result)
# Out:
# Tester= 0
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 0.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 1
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 1.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 2
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 2.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 3
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 3.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 4
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 4.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31

# %% [markdown]
# ---
# # 2 Ru - 10min

# %%
Ru_10min_result = GetResult("Results/Ru_10min")
# Out:
# ================================================================
# Tester= 0 |file_path =  Results/Ru_10min/Result_0.pkl
#
# ================================================================
# Tester= 1 |file_path =  Results/Ru_10min/Result_1.pkl
#
# ================================================================
# Tester= 2 |file_path =  Results/Ru_10min/Result_2.pkl
#
# ================================================================
# Tester= 3 |file_path =  Results/Ru_10min/Result_3.pkl
#
# ================================================================
# Tester= 4 |file_path =  Results/Ru_10min/Result_4.pkl

# %%
Ru_10min_Offset_Average = OffSetAverage(Ru_10min_result[0:9:2])

Benchmark = Ru_10min_Offset_Average.GetBenchmark()
AveEqCurve = Ru_10min_Offset_Average.GetAveEquityCurve()

# Plot
fig, ax = plt.subplots(1,2, figsize=(20,6))
Benchmark['insample'].plot(ax=ax[0],label='b')
AveEqCurve['insample'].plot(ax=ax[0])
ax[0].legend(['b',2,3,4,5,6,7,8])
ax[0].set_title('Equity_Curve - insample - OffsetAverage')

Benchmark['outsample'].plot(ax=ax[1],label='b')
AveEqCurve['outsample'].plot(ax=ax[1])
ax[1].legend(['b',2,3,4,5,6,7,8])
ax[1].set_title('Equity_Curve - Outsample - OffsetAverage')
# Out:
# Text(0.5,1,'Equity_Curve - Outsample - OffsetAverage')

# %%
PlotResult(Ru_10min_result)
# Out:
# Tester= 0
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 0.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 1
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 1.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 2
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 2.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 3
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 3.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 4
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 4.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31

# %% [markdown]
# ---
# # 3 Ru - 15min

# %%
Ru_15min_result = GetResult("Results/Ru_15min")
# Out:
# ================================================================
# Tester= 0 |file_path =  Results/Ru_15min/Result_0.pkl
#
# ================================================================
# Tester= 1 |file_path =  Results/Ru_15min/Result_1.pkl
#
# ================================================================
# Tester= 2 |file_path =  Results/Ru_15min/Result_2.pkl
#
# ================================================================
# Tester= 3 |file_path =  Results/Ru_15min/Result_3.pkl
#
# ================================================================
# Tester= 4 |file_path =  Results/Ru_15min/Result_4.pkl

# %%
Ru_15min_Offset_Average = OffSetAverage(Ru_15min_result[0:9:2])

Benchmark = Ru_15min_Offset_Average.GetBenchmark()
AveEqCurve = Ru_15min_Offset_Average.GetAveEquityCurve()

# Plot
fig, ax = plt.subplots(1,2, figsize=(20,6))
Benchmark['insample'].plot(ax=ax[0],label='b')
AveEqCurve['insample'].plot(ax=ax[0])
ax[0].legend(['b',2,3,4,5,6,7,8])
ax[0].set_title('Equity_Curve - insample - OffsetAverage')

Benchmark['outsample'].plot(ax=ax[1],label='b')
AveEqCurve['outsample'].plot(ax=ax[1])
ax[1].legend(['b',2,3,4,5,6,7,8])
ax[1].set_title('Equity_Curve - Outsample - OffsetAverage')
# Out:
# Text(0.5,1,'Equity_Curve - Outsample - OffsetAverage')

# %%
PlotResult(Ru_15min_result)
# Out:
# Tester= 0
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 15
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 0.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 1
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 15
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 1.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 2
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 15
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 2.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 3
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 15
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 3.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 4
# symbol = ru
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 15
# threshold = 0
# threshold_type = 1
# tca = -1
# offset = 4.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
