# %% [markdown]
# # 0. Run the backtest code

# %%
# Bu 5min test
# !python Main.py -o ./Results/Bu_5min -c Config/Bu_5min.json > /dev/null

# %%
# Bu 10min test
# !python Main.py -o ./Results/Bu_10min -c Config/Bu_10min.json > /dev/null
# Out:
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# Bu 15min test
# !python Main.py -o ./Results/Bu_15min -c Config/Bu_15min.json > /dev/null
# Out:
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
from PostProcessing import GetResult
from PostProcessing import OffSetAverage

def PlotResult(TesterResults):
    for ID, tester in enumerate(TesterResults):
        print("Tester=",ID)
        
        params = tester["globalPara"]
        for key, item in tester["localPara"].items():
            print("{} = {}".format(key, item))

        fig, ax = plt.subplots(1,2,figsize=(20,6))
        tester["insample"].ensemble.ensembles[0].result.benchmark.plot(ax=ax[0])
        tester["insample"].plot(ax=ax[0])
        tester["outsample"].ensemble.ensembles[0].result.benchmark.plot(ax=ax[1])
        tester["outsample"].plot(ax=ax[1])
        
        ax[0].set_xlabel("Date")
        ax[0].set_title("Equity curve - Insample")
        ax[1].set_xlabel("Datae")
        ax[1].set_title("Equity curve - Outsample")
        plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. Bu - 5min

# %%
Bu_5min_result = GetResult("Results/Bu_5min")
# Out:
# ================================================================
# Tester= 0 |file_path =  Results/Bu_5min/Result_0.pkl
#
# ================================================================
# Tester= 1 |file_path =  Results/Bu_5min/Result_1.pkl
#
# ================================================================
# Tester= 2 |file_path =  Results/Bu_5min/Result_2.pkl
#
# ================================================================
# Tester= 3 |file_path =  Results/Bu_5min/Result_3.pkl
#
# ================================================================
# Tester= 4 |file_path =  Results/Bu_5min/Result_4.pkl

# %% [markdown]
# ## 1.0 Bu - 5min offset average

# %%
Bu_5min_Offset_Average = OffSetAverage(Bu_5min_result)

Benchmark = Bu_5min_Offset_Average.GetBenchmark()
AveEqCurve = Bu_5min_Offset_Average.GetAveEquityCurve()

# Plot
fig, ax = plt.subplots(1,2, figsize=(20,6))
Benchmark['insample'].plot(ax=ax[0],label='b')
AveEqCurve['insample'].plot(ax=ax[0])
ax[0].legend(['b',2,3,4,5,6,7,8])
ax[0].set_title('Equity_Curve - insample - OffsetAverage')

Benchmark['outsample'].plot(ax=ax[1],label='b')
AveEqCurve['outsample'].plot(ax=ax[1])
ax[1].legend(['b',2,3,4,5,6,7,8])
ax[1].set_title('Equity_Curve - Outsample - OffsetAverage')
# Out:
# Text(0.5,1,'Equity_Curve - Outsample - OffsetAverage')

# %% [markdown]
# ## 1.1 Bu - 5min - no offset average

# %%
PlotResult(Bu_5min_result)
# Out:
# Tester= 0
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 0.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 1
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 1.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 2
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 2.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 3
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 3.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 4
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 5
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 4.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31

# %% [markdown]
# ---
# # 2 Bu - 10min

# %%
Bu_10min_result = GetResult("Results/Bu_10min")
# Out:
# ================================================================
# Tester= 0 |file_path =  Results/Bu_10min/Result_0.pkl
#
# ================================================================
# Tester= 1 |file_path =  Results/Bu_10min/Result_1.pkl
#
# ================================================================
# Tester= 2 |file_path =  Results/Bu_10min/Result_2.pkl
#
# ================================================================
# Tester= 3 |file_path =  Results/Bu_10min/Result_3.pkl
#
# ================================================================
# Tester= 4 |file_path =  Results/Bu_10min/Result_4.pkl
#
# ================================================================
# Tester= 5 |file_path =  Results/Bu_10min/Result_5.pkl
#
# ================================================================
# Tester= 6 |file_path =  Results/Bu_10min/Result_6.pkl
#
# ================================================================
# Tester= 7 |file_path =  Results/Bu_10min/Result_7.pkl
#
# ================================================================
# Tester= 8 |file_path =  Results/Bu_10min/Result_8.pkl
#
# ================================================================
# Tester= 9 |file_path =  Results/Bu_10min/Result_9.pkl

# %%
Bu_10min_Offset_Average = OffSetAverage(Bu_10min_result[0:9:2])

Benchmark = Bu_10min_Offset_Average.GetBenchmark()
AveEqCurve = Bu_10min_Offset_Average.GetAveEquityCurve()

# Plot
fig, ax = plt.subplots(1,2, figsize=(20,6))
Benchmark['insample'].plot(ax=ax[0],label='b')
AveEqCurve['insample'].plot(ax=ax[0])
ax[0].legend(['b',2,3,4,5,6,7,8])
ax[0].set_title('Equity_Curve - insample - OffsetAverage')

Benchmark['outsample'].plot(ax=ax[1],label='b')
AveEqCurve['outsample'].plot(ax=ax[1])
ax[1].legend(['b',2,3,4,5,6,7,8])
ax[1].set_title('Equity_Curve - Outsample - OffsetAverage')
# Out:
# Text(0.5,1,'Equity_Curve - Outsample - OffsetAverage')

# %%
PlotResult(Bu_10min_result)
# Out:
# Tester= 0
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 0.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 1
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 1.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 2
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 2.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 3
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 3.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 4
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 4.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 5
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 5.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 6
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 6.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 7
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 7.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 8
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 8.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
# Tester= 9
# symbol = bu
# SignalPrice = AvePrice2
# TrainPrice = AvePrice2
# TestPrice = MidPrice
# frequency = 10
# threshold = 0
# threshold_type = 1
# tca = None
# offset = 9.1
# start = 2016-01-01
# split = 2016-07-01
# valid_split = 2016-10-01
# end = 2016-12-31
