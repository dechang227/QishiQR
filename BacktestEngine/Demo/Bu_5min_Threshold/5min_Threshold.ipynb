# %%
import sys
sys.path.append("/home/runmin/Documents/Qishi/QishiQR/BacktestEngine")

from glob import glob
import pickle
import matplotlib.pyplot as plt
import Backtesting
import pandas as pd

# %% [markdown]
# #  5min Frequeny - Train: AvePrice2,  Signal: AvePrice2

# %%
result_folder = './Results_train_ave_signal_ave/'
files = glob(result_folder+"*.pkl")



Tester_Results = []

for idx, file in enumerate(files):
    with  open(file,"rb") as f:
        Tester_Results.append(pickle.load(f))

    print("\n=======================")
    params = Tester_Results[-1]["globalPara"]
    print(idx,":{syb}".format(syb=params.symbol))
    print(Tester_Results[-1]["localPara"])
    fig, ax = plt.subplots()
    Tester_Results[-1]["model"].ensemble.ensembles[0].result.benchmark.plot(ax=ax)
    Tester_Results[-1]["model"].plot(ax=ax)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.xlabel("Date")
    plt.show()
# Out:
# =======================
# 0 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.6}
# =======================
# 1 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 2.1}
# =======================
# 2 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.1}
# =======================
# 3 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.3}
# =======================
# 4 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.7}
# =======================
# 5 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 2.1}
# =======================
# 6 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 1.0}
# =======================
# 7 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.4}
# =======================
# 8 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.1}
# =======================
# 9 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 2.1}
# =======================
# 10 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 4.1}
# =======================
# 11 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 3.1}
# =======================
# 12 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.5}
# =======================
# 13 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.1}
# =======================
# 14 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.3}
# =======================
# 15 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.8}
# =======================
# 16 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.7}
# =======================
# 17 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.8}
# =======================
# 18 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.6}
# =======================
# 19 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.9}
# =======================
# 20 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.4}
# =======================
# 21 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.8}
# =======================
# 22 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 1.0}
# =======================
# 23 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 4.1}
# =======================
# 24 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.9}
# =======================
# 25 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.2}
# =======================
# 26 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 1.1}
# =======================
# 27 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 3.1}
# =======================
# 28 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 3.1}
# =======================
# 29 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.7}
# =======================
# 30 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.2}
# =======================
# 31 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.6}
# =======================
# 32 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.5}
# =======================
# 33 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.9}
# =======================
# 34 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.3}
# =======================
# 35 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 1.1}
# =======================
# 36 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.4}
# =======================
# 37 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 1.0}
# =======================
# 38 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.2}
# =======================
# 39 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 4.1}
# =======================
# 40 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.5}
# =======================
# 41 :bu
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 1.1}

# %% [markdown]
# #### Offset average

# %%
Time_index = Tester_Results[0]["model"].ensemble.ensembles[0].result.index
Averaged_return = pd.DataFrame(index=Time_index)
Averaged_return["Benchmark"] = Tester_Results[0]["model"].ensemble.ensembles[0].result.benchmark

for idx, model_order in enumerate([2,3,4,5,6,7,8]):
    equity_curve = 0
    for offset_idx, tester in enumerate(Tester_Results, start=1):
        equity_curve += tester["model"].ensemble.ensembles[idx].result.equitycurve.values
    Averaged_return[model_order] = equity_curve/offset_idx

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.gca()
Averaged_return.plot(ax=ax)
ax.set_title("Freq=5min, Offset averaged")
ax.set_ylabel("Equity Curve")
ax.set_xlabel("Date")
# Out:
# Text(0.5,0,'Date')

# %% [markdown]
# #  5min Frequeny - Train: AvePrice2,  Signal: MidPrice

# %%
result_folder = './Results_train_ave_signal_mid/'
files = glob(result_folder+"*.pkl")



Tester_Results = []

for idx, file in enumerate(files):
    with  open(file,"rb") as f:
        Tester_Results.append(pickle.load(f))

    print("\n=======================")
    params = Tester_Results[-1]["globalPara"]
    print(idx,":{syb}".format(syb=params.symbol))
    print(Tester_Results[-1]["localPara"])
    fig, ax = plt.subplots()
    Tester_Results[-1]["model"].ensemble.ensembles[0].result.benchmark.plot(ax=ax)
    Tester_Results[-1]["model"].plot(ax=ax)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.xlabel("Date")
    plt.show()
# Out:
# =======================
# 0 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.0}
# =======================
# 1 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.1}
# =======================
# 2 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.0}
# =======================
# 3 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.0}
# =======================
# 4 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.5}
# =======================
# 5 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.001, 'tca': -1, 'offset': 0.1}
# =======================
# 6 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0.005, 'tca': -1, 'offset': 0.5}
# =======================
# 7 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.5}
# =======================
# 8 :bu
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.1}

# %% [markdown]
# ### Offset average

# %%
Time_index = Tester_Results[0]["model"].ensemble.ensembles[0].result.index
Averaged_return = pd.DataFrame(index=Time_index)
Averaged_return["Benchmark"] = Tester_Results[0]["model"].ensemble.ensembles[0].result.benchmark

for idx, model_order in enumerate([2,3,4,5,6,7,8]):
    equity_curve = 0
    for offset_idx, tester in enumerate(Tester_Results, start=1):
        equity_curve += tester["model"].ensemble.ensembles[idx].result.equitycurve.values
    Averaged_return[model_order] = equity_curve/offset_idx
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-bdbc268eea95> in <module>()
#       6     equity_curve = 0
#       7     for offset_idx, tester in enumerate(Tester_Results, start=1):
# ----> 8         equity_curve += tester["model"].ensemble.ensembles[idx].result.equitycurve.values
#       9     Averaged_return[model_order] = equity_curve/offset_idx
#
# ValueError: operands could not be broadcast together with shapes (2774,) (2655,) (2774,)

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.gca()
Averaged_return.plot(ax=ax)
ax.set_title("Freq=5min, Offset averaged - Train:AveragePrice, Signal:MidPrice")
ax.set_ylabel("Equity Curve")
ax.set_xlabel("Date")
# Out:
# Text(0.5,0,'Date')
