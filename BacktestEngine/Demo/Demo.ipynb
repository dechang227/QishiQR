# %% [markdown]
# # Run the backtest code

# %%
# !python Main.py > Output
# Out:
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # Get results

# %%
import sys
sys.path.append("/home/runmin/Documents/Qishi/QishiQR/BacktestEngine")

from glob import glob
import pickle
import matplotlib.pyplot as plt
import Backtesting
files = glob("./Results/*.pkl")



Tester_Results = []

for idx, file in enumerate(files):
    with  open(file,"rb") as f:
        Tester_Results.append(pickle.load(f))

    print("\n=======================")
    params = Tester_Results[-1]["globalPara"]
    print(idx,":{} - Train:{}, Signal:{}, Test:{}"
          .format(params.symbol, params.TrainPrice, params.SignalPrice, params.TestPrice))
    print(Tester_Results[-1]["localPara"])
    fig, ax = plt.subplots()
    Tester_Results[-1]["model"].ensemble.ensembles[0].result.benchmark.plot(ax=ax)
    Tester_Results[-1]["model"].plot(ax=ax)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.xlabel("Date")
    plt.show()
    

def Offset_Average(Tester_Results):
    pass
# Out:
# =======================
# 0 :bu - Train:AvePrice2, Signal:AvePrice2, Test:MidPrice
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'TestPrice': 'MidPrice', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.1}
# =======================
# 1 :bu - Train:AvePrice2, Signal:AvePrice2, Test:MidPrice
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'TestPrice': 'MidPrice', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 3.1}
# =======================
# 2 :bu - Train:AvePrice2, Signal:AvePrice2, Test:MidPrice
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'TestPrice': 'MidPrice', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 4.1}
# =======================
# 3 :bu - Train:AvePrice2, Signal:AvePrice2, Test:MidPrice
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'TestPrice': 'MidPrice', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 2.1}
# =======================
# 4 :bu - Train:AvePrice2, Signal:AvePrice2, Test:MidPrice
# {'SignalPrice': 'AvePrice2', 'TrainPrice': 'AvePrice2', 'TestPrice': 'MidPrice', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 1.1}
