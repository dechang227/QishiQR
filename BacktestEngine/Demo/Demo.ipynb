# %% [markdown]
# # Run the backtest code

# %%
# !python Main.py > Output
# Out:
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # Get results

# %%
import sys
sys.path.append("/home/runmin/Documents/Qishi/QishiQR/BacktestEngine")

from glob import glob
import pickle
import matplotlib.pyplot as plt
import Backtesting
files = glob("./Results/*.pkl")

for idx, file in enumerate(files):
    with  open(file,"rb") as f:
        result = pickle.load(f)

    print("\n=======================")
    params = result["globalPara"]
    print(idx,":{syb} - {px_type}".format(syb=params.symbol, px_type=params.price))
    print(result["localPara"])
    fig, ax = plt.subplots()
    result["model"].ensemble.ensembles[0].result.benchmark.plot(ax=ax)
    result["model"].plot(ax=ax)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.show()
# Out:
# ...
# 0 :bu - AvePrice2
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 0.1}
# ...
# 1 :bu - AvePrice2
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 3.1}
# ...
# 2 :bu - AvePrice2
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 4.1}
# ...
# 3 :bu - AvePrice2
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 2.1}
# ...
# 4 :bu - AvePrice2
# {'SignalPrice': 'MidPrice', 'TrainPrice': 'AvePrice2', 'frequency': 5, 'threshold': 0, 'tca': -1, 'offset': 1.1}

# %%
result['model'].performance
# Out:
#    Annualized Volatility  Average Daily Return  Average Negative Return  \
# 0               0.298114              0.000019                -0.002233
# 1               0.329119              0.001558                -0.002426
# 2               0.309354             -0.000003                -0.002422
# 3               0.308371              0.000182                -0.002621
# 4               0.302341              0.000540                -0.002835
# 5               0.307152              0.002339                -0.003136
# 6               0.286771             -0.002993                -0.004041
#
#    Average Positive Return  Average Return per Trade  Largest Losing Trade  \
# 0                 0.003917              8.331152e-07             -0.047476
# 1                 0.003478              7.061545e-05             -0.048367
# 2                 0.003220             -1.164542e-07             -0.048367
# 3                 0.003308              8.135054e-06             -0.049258
# ...

# %%
result['model'].ensemble.ensembles[0]
