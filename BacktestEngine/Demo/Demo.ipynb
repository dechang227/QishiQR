# %% [markdown]
# # Run the backtest code

# %%
# !python Main.py > Output
# Out:
# /home/runmin/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # Get results

# %%
from glob import glob
import pickle
import matplotlib.pyplot as plt
files = glob("./Results/*.pkl")

for idx, file in enumerate(files):
    with  open(file,"rb") as f:
        result = pickle.load(f)

    print("\n=======================")
    params = result["globalPara"]
    print(idx,":{syb} - {px_type}".format(syb=params.symbol, px_type=params.price))
    print(result["localPara"])
    fig, ax = plt.subplots()
    result["model"].ensemble.ensembles[0].result.benchmark.plot(ax=ax)
    result["model"].plot(ax=ax)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.show()
# Out:
# =======================
# 0 :bu - LastPrice
# {'frequency': 30, 'threshold': 0.0005, 'tca': -1}
# =======================
# 1 :bu - LastPrice
# {'frequency': 15, 'threshold': 0.001, 'tca': -1}
# =======================
# 2 :bu - LastPrice
# {'frequency': 15, 'threshold': 0.0025, 'tca': -1}
# =======================
# 3 :bu - LastPrice
# {'frequency': 10, 'threshold': 0.0015, 'tca': -1}
# =======================
# 4 :bu - LastPrice
# {'frequency': 10, 'threshold': 0.005, 'tca': -1}
# =======================
# 5 :bu - LastPrice
# {'frequency': 15, 'threshold': 0.0005, 'tca': -1}
# =======================
# 6 :bu - LastPrice
# {'frequency': 30, 'threshold': 0, 'tca': -1}
# =======================
# 7 :bu - LastPrice
# {'frequency': 5, 'threshold': 0, 'tca': -1}
# =======================
# 8 :bu - LastPrice
# {'frequency': 30, 'threshold': 0.0015, 'tca': -1}
# =======================
# 9 :bu - LastPrice
# {'frequency': 30, 'threshold': 0.001, 'tca': -1}
# =======================
# 10 :bu - LastPrice
# {'frequency': 10, 'threshold': 0.0005, 'tca': -1}
# =======================
# 11 :bu - LastPrice
# {'frequency': 5, 'threshold': 0.0015, 'tca': -1}
# =======================
# 12 :bu - LastPrice
# {'frequency': 30, 'threshold': 0.005, 'tca': -1}
# =======================
# 13 :bu - LastPrice
# {'frequency': 30, 'threshold': 0.0025, 'tca': -1}
# =======================
# 14 :bu - LastPrice
# {'frequency': 15, 'threshold': 0.0015, 'tca': -1}
# =======================
# 15 :bu - LastPrice
# {'frequency': 15, 'threshold': 0, 'tca': -1}
# =======================
# 16 :bu - LastPrice
# {'frequency': 10, 'threshold': 0, 'tca': -1}
# =======================
# 17 :bu - LastPrice
# {'frequency': 5, 'threshold': 0.005, 'tca': -1}
# =======================
# 18 :bu - LastPrice
# {'frequency': 5, 'threshold': 0.0025, 'tca': -1}
# =======================
# 19 :bu - LastPrice
# {'frequency': 10, 'threshold': 0.001, 'tca': -1}
# =======================
# 20 :bu - LastPrice
# {'frequency': 5, 'threshold': 0.001, 'tca': -1}
# =======================
# 21 :bu - LastPrice
# {'frequency': 10, 'threshold': 0.0025, 'tca': -1}
# =======================
# 22 :bu - LastPrice
# {'frequency': 15, 'threshold': 0.005, 'tca': -1}
# =======================
# 23 :bu - LastPrice
# {'frequency': 5, 'threshold': 0.0005, 'tca': -1}
