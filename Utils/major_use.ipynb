# %%
from MajorContract import MajorContracts

# %%
dir(MajorContracts)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'create_major',
#  'create_major_overlap',
#  'ternary',
#  'word_prob']

# %%
# %load_ext autoreload

# %%
rb_mj = MajorContracts(topdir='C:/Users/Documents/Qishi_QR/data', maturity={'1605':['2015-11-1','2016-3-1'], \
                                                                                  '1609':['2016-3-1','2016-6-1']})

# %%
df_rb_mj = rb_mj.create_major()

# %%
df_rb_mj
# Out:
#                     InstrumentID        Date     TimeStamp  LastPrice  \
# 2016-01-04 09:00:06       rb1605  20160104.0  1.451869e+12     1840.0
# 2016-01-04 09:15:06       rb1605  20160104.0  1.451870e+12     1806.0
# 2016-01-04 09:30:06       rb1605  20160104.0  1.451871e+12     1808.0
# 2016-01-04 09:45:06       rb1605  20160104.0  1.451872e+12     1798.0
# 2016-01-04 10:00:06       rb1605  20160104.0  1.451873e+12     1803.0
# 2016-01-04 10:30:06       rb1605  20160104.0  1.451875e+12     1804.0
# 2016-01-04 10:45:06       rb1605  20160104.0  1.451876e+12     1794.0
# 2016-01-04 11:00:06       rb1605  20160104.0  1.451876e+12     1796.0
# 2016-01-04 11:15:06       rb1605  20160104.0  1.451877e+12     1792.0
# 2016-01-04 13:30:06       rb1605  20160104.0  1.451885e+12     1785.0
# 2016-01-04 13:45:06       rb1605  20160104.0  1.451886e+12     1792.0
# 2016-01-04 14:00:06       rb1605  20160104.0  1.451887e+12     1791.0
# ...

# %%
rb_mj2 = MajorContracts(topdir='C:/Users/Documents/Qishi_QR/data', maturity={'1609':['2015-11-1','2016-8-1'], \
                            '1705':['2016-6-1','2017-3-1']}, transitions={'1609':'2016-7-1', '1705':'2017-2-1'})

# %%
df_rb_mj2, ptb = rb_mj2.create_major_overlap()

# %%
df_rb_mj2.head(2)
# Out:
#                     InstrumentID        Date     TimeStamp  LastPrice  \
# 2016-01-04 09:00:06       rb1609  20160104.0  1.451869e+12     1833.0
# 2016-01-04 09:15:06       rb1609  20160104.0  1.451870e+12     1818.0
#
#                      HighPrice  LowPrice  Volume  Turnover  AccVolume  \
# 2016-01-04 09:00:06     1853.0    1813.0     0.0       0.0       28.0
# 2016-01-04 09:15:06     1853.0    1813.0     0.0       0.0      446.0
#
#                      AccTurnover    ...      BidVolume2  BidVolume3  \
# 2016-01-04 09:00:06     515780.0    ...             0.0         0.0
# 2016-01-04 09:15:06    8131120.0    ...             0.0         0.0
#
#                      BidVolume4  BidVolume5  Type  AveragePrice  \
# 2016-01-04 09:00:06         0.0         0.0  -1.0        1842.0
# 2016-01-04 09:15:06         0.0         0.0  -1.0        1823.0
#
#                      UpperLimitPrice  LowerLimitPrice    UpdateTime  Direction
# ...

# %%
rb1609 = df_rb_mj2[df_rb_mj2.InstrumentID=='rb1609']

# %%
rb1609.tail()
# Out:
#                     InstrumentID        Date     TimeStamp  LastPrice  \
# 2016-06-30 22:45:06       rb1609  20160630.0  1.467298e+12     2287.0
# 2016-06-30 23:00:06       rb1609  20160630.0  1.467299e+12     2289.0
# 2016-06-30 23:15:06       rb1609  20160630.0  1.467299e+12     2289.0
# 2016-06-30 23:30:06       rb1609  20160630.0  1.467299e+12     2289.0
# 2016-06-30 23:45:06       rb1609  20160630.0  1.467299e+12     2289.0
#
#                      HighPrice  LowPrice  Volume  Turnover  AccVolume  \
# 2016-06-30 22:45:06     2315.0    2283.0     0.0       0.0     7068.0
# 2016-06-30 23:00:06     2315.0    2281.0     0.0       0.0     7462.0
# 2016-06-30 23:15:06     2315.0    2281.0     0.0       0.0     7462.0
# 2016-06-30 23:30:06     2315.0    2281.0     0.0       0.0     7462.0
# 2016-06-30 23:45:06     2315.0    2281.0     0.0       0.0     7462.0
#
#                      AccTurnover    ...      BidVolume2  BidVolume3  \
# ...

# %%
ptb.keys()
# Out:
# dict_keys(['1609', '1705'])

# %%
ptb1609 = ptb['1609']

# %%
ptb1609.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1093 entries,  to 222222
# Data columns (total 8 columns):
# prior      1093 non-null object
# 0          1093 non-null int64
# 1          1093 non-null int64
# 2          1093 non-null int64
# total      1093 non-null int64
# max        1093 non-null object
# max_pct    901 non-null float64
# offset     1093 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 76.9+ KB

# %%
ptb1609
# Out:
# move      prior     0     1     2  total max   max_pct  offset
# prior
#               p  7448  2152  2247  11847   0  0.628682     0.1
# 0            p0  6704   376   367   7447   0  0.900228     0.1
# 1            p1   357   413  1382   2152   2  0.642193     0.1
# 2            p2   386  1363   498   2247   1  0.606587     0.1
# 00          p00  6400   151   152   6703   0  0.954796     0.1
# 01          p01    35    58   283    376   2  0.752660     0.1
# 02          p02    38   261    68    367   1  0.711172     0.1
# 10          p10   142    36   179    357   2  0.501401     0.1
# 11          p11    62   103   248    413   2  0.600484     0.1
# 12          p12   283   830   269   1382   1  0.600579     0.1
# 20          p20   162   188    36    386   1  0.487047     0.1
# 21          p21   260   252   851   1363   2  0.624358     0.1
# 22          p22    65   272   161    498   1  0.546185     0.1
# 000        p000  6145   129   125   6399   0  0.960306     0.1
# ...
